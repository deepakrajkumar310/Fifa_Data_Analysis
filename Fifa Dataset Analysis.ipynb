# %% [markdown]
# ## Data Observation

# %% [markdown]
# It provides the players data for the Career Mode from FIFA 15 to FIFA 20. The data allows multiple comparison of the same players across the last 6 versions of the videogame.

# %% [markdown]
# ## Loading the Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Reading Data

# %%
fifa_df = pd.read_csv("players_20.csv")

# %%
fifa_df.head()
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2     190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3     200389  https://sofifa.com/player/200389/jan-oblak/20/...
# 4     183277  https://sofifa.com/player/183277/eden-hazard/2...
#
#           short_name                            long_name  age         dob  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini   32  1987-06-24
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# 2          Neymar Jr        Neymar da Silva Santos Junior   27  1992-02-05
# 3           J. Oblak                            Jan Oblak   26  1993-01-07
# 4          E. Hazard                          Eden Hazard   28  1991-01-07
#
#    height_cm  weight_kg nationality                 club  ...   lwb   ldm  \
# ...

# %%
fifa_df.tail()
# Out:
#        sofifa_id                                         player_url  \
# 18273     245006  https://sofifa.com/player/245006/shuai-shao/20...
# 18274     250995  https://sofifa.com/player/250995/mingjie-xiao/...
# 18275     252332  https://sofifa.com/player/252332/wei-zhang/20/...
# 18276     251110  https://sofifa.com/player/251110/haijian-wang/...
# 18277     233449  https://sofifa.com/player/233449/ximing-pan/20...
#
#          short_name     long_name  age         dob  height_cm  weight_kg  \
# 18273    Shao Shuai            邵帅   22  1997-03-10        186         79
# 18274  Xiao Mingjie  Mingjie Xiao   22  1997-01-01        177         66
# 18275     Zhang Wei            张威   19  2000-05-16        186         75
# 18276  Wang Haijian           汪海健   18  2000-08-02        185         74
# 18277    Pan Ximing           潘喜明   26  1993-01-11        182         78
#
#       nationality                           club  ...   lwb   ldm   cdm   rdm  \
# ...

# %%
fifa_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18278 entries, 0 to 18277
# Columns: 104 entries, sofifa_id to rb
# dtypes: float64(16), int64(45), object(43)
# memory usage: 14.5+ MB

# %%
fifa_df.columns
# Out:
# Index(['sofifa_id', 'player_url', 'short_name', 'long_name', 'age', 'dob',
#        'height_cm', 'weight_kg', 'nationality', 'club',
#        ...
#        'lwb', 'ldm', 'cdm', 'rdm', 'rwb', 'lb', 'lcb', 'cb', 'rcb', 'rb'],
#       dtype='object', length=104)

# %%
fifa_df.describe()
# Out:
#            sofifa_id           age     height_cm     weight_kg       overall  \
# count   18278.000000  18278.000000  18278.000000  18278.000000  18278.000000
# mean   219738.864482     25.283291    181.362184     75.276343     66.244994
# std     27960.200461      4.656964      6.756961      7.047744      6.949953
# min       768.000000     16.000000    156.000000     50.000000     48.000000
# 25%    204445.500000     22.000000    177.000000     70.000000     62.000000
# 50%    226165.000000     25.000000    181.000000     75.000000     66.000000
# 75%    240795.750000     29.000000    186.000000     80.000000     71.000000
# max    252905.000000     42.000000    205.000000    110.000000     94.000000
#
#           potential     value_eur       wage_eur  international_reputation  \
# count  18278.000000  1.827800e+04   18278.000000              18278.000000
# mean      71.546887  2.484038e+06    9456.942773                  1.103184
# ...

# %%
fifa_df.describe(include="O")
# Out:
#                                                player_url    short_name  \
# count                                               18278         18278
# unique                                              18278         17354
# top     https://sofifa.com/player/158023/lionel-messi/...  J. Rodríguez
# freq                                                    1            11
#
#          long_name         dob nationality          club player_positions  \
# count        18278       18278       18278         18278            18278
# unique       18218        6142         162           698              643
# top     Liam Kelly  1992-02-29     England  FC Barcelona               CB
# freq             3         113        1667            33             2322
#
#        preferred_foot      work_rate body_type  ...    lwb    ldm    cdm  \
# count           18278          18278     18278  ...  16242  16242  16242
# unique              2              9        10  ...     98     98     98
# ...

# %% [markdown]
# ### Conclusion:
#
# It is observed that there are 61 numerical and 43 categorical columns in the data from describe() function.

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ### Exploring *"sofifa_id"* column

# %%
fifa_df["sofifa_id"].nunique()
# Out:
# 18278

# %%
len(fifa_df)
# Out:
# 18278

# %%
fifa_df["sofifa_id"].unique()
# Out:
# array([158023,  20801, 190871, ..., 252332, 251110, 233449], dtype=int64)

# %% [markdown]
# #### Conclusion:
#
# * *sofifa_id* is a pseudo-numerical column. It is just the id of players and doesnot have any number sense to it.
# * The number of unique values of fifa's identifier for the players is equal to the length of the dataframe, which means that there is no repetition of data and that implies that there are no duplicate rows in the data.

# %% [markdown]
# ### Exploring *"short_name"* column

# %%
fifa_df["short_name"].nunique()
# Out:
# 17354

# %%
len(fifa_df)
# Out:
# 18278

# %%
fifa_df["short_name"].unique()
# Out:
# array(['L. Messi', 'Cristiano Ronaldo', 'Neymar Jr', ..., 'Xiao Mingjie',
#        'Wang Haijian', 'Pan Ximing'], dtype=object)

# %%
fifa_df["short_name"].value_counts()
# Out:
# J. Rodríguez    11
# Paulinho         9
# J. García        8
# J. Williams      7
# J. Hernández     7
#                 ..
# Eguaras          1
# S. Mugoša        1
# Crislan          1
# L. Paganini      1
# Pan Ximing       1
# Name: short_name, Length: 17354, dtype: int64

# %%
from wordcloud import WordCloud

# %%
text = " ".join(fifa_df["short_name"].to_list())
wordcloud = WordCloud(background_color="grey").generate_from_text(text)

plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.margins(x=0,y=0)
plt.show()

# %% [markdown]
# #### Conclusion:
#
# It can be observed that few people have the same name. We can then use their long_name to differentiate them.

# %% [markdown]
# ### Exploring *"age"* column

# %%
fifa_df["age"].mean()
# Out:
# 25.283291388554545

# %%
fifa_df["age"].min()
# Out:
# 16

# %%
fifa_df["age"].max()
# Out:
# 42

# %%
fifa_df["age"].median()
# Out:
# 25.0

# %%
fifa_df["age"].std()
# Out:
# 4.656964497822004

# %%
fifa_df["age"].var()
# Out:
# 21.687318333974556

# %%
fifa_df["age"].skew()
# Out:
# 0.38061976075931975

# %% [markdown]
# #### Looking at the Distribution of column

# %%
sns.histplot(fifa_df["age"],color="aqua")

plt.title("Histogram plot of age",y=1.02)
plt.xlabel("age")
plt.ylabel("frequency")
plt.show()

# %%
sns.displot(fifa_df["age"],kind="kde",color="green")

plt.title("Density plot of age",y=1.02)
plt.xlabel("age")
plt.ylabel("probability")
plt.show()

# %% [markdown]
# #### Looking for Outliers in the column

# %%
fifa_df["age"].quantile(0.10),fifa_df["age"].quantile(0.25),fifa_df["age"].quantile(0.50),fifa_df["age"].quantile(0.75),fifa_df["age"].quantile(0.90)
# Out:
# (19.0, 22.0, 25.0, 29.0, 32.0)

# %%
sns.boxplot(fifa_df["age"],orient="h",color="plum")

plt.title("Box plot for age",y=1.02)
plt.xlabel("age")
plt.show()

# %%
sns.violinplot(fifa_df["age"],orient="h",color="aquamarine")

plt.title("Violin plot for age",y=1.02)
plt.xlabel("age")
plt.show()

# %% [markdown]
# #### Conclusion:
#
# **age** has a symmetrical distribution i.e., it is not skewed and has a skewness value of 0.381
#
# * The Density curve of *age* column is centered along mean 25.283 with standard deviation of 4.656.
# * The range of the age is from 16 to 42.
# * Most of the players are of age 20 to 30.
# * 10% of the players are of age 19 and below.
# * 25% of the players are of age 22 and below.
# * 50% of the players are of age 25 and below.
# * 75% of the players are of age 29 and below.
# * 90% of the players are of age 32 and below.
# * *age* column is having outliers (i.e., extreme values) towards higher side.
#
# **age** column can be further explored with other columns

# %% [markdown]
# ### Exploring *"dob"* column

# %%
fifa_df["dob"].min()
# Out:
# '1977-01-21'

# %%
fifa_df["dob"].max()
# Out:
# '2002-08-08'

# %%
fifa_df["dob"].value_counts()
# Out:
# 1992-02-29    113
# 1984-02-29    111
# 1988-02-29    110
# 1997-01-01     15
# 2001-01-01     13
#              ...
# 1982-12-23      1
# 1984-06-22      1
# 1984-04-16      1
# 1982-01-08      1
# 2000-07-09      1
# Name: dob, Length: 6142, dtype: int64

# %% [markdown]
# #### Conclusion:
#
# * The range of date of births are from 1977-01-21 to 2002-08-08.
# * 334 players are having the same date and month of birth (i.e., 29th February) although there may be a change in year. 113 of them were born in 1992, 111 are born in 1984 and 110 are born in 1988.
# * This **dob** column can be discarded as it might be of no much help.

# %% [markdown]
# ### Exploring *"height_cm"* column

# %%
fifa_df["height_cm"].mean()
# Out:
# 181.36218404639456

# %%
fifa_df["height_cm"].min()
# Out:
# 156

# %%
fifa_df["height_cm"].max()
# Out:
# 205

# %%
fifa_df["height_cm"].median()
# Out:
# 181.0

# %%
fifa_df["height_cm"].std()
# Out:
# 6.75696136370041

# %%
fifa_df["height_cm"].var()
# Out:
# 45.6565268705401

# %%
fifa_df["height_cm"].skew()
# Out:
# -0.03819688576323108

# %% [markdown]
# #### Looking at the Distribution of column

# %%
sns.histplot(fifa_df["height_cm"],color="purple")

plt.title("Histogram plot of height_cm",y=1.02)
plt.xlabel("height_cm")
plt.ylabel("frequency")
plt.show()

# %%
sns.displot(fifa_df["height_cm"],kind="kde",color="indigo")

plt.title("Density plot of height_cm",y=1.02)
plt.xlabel("height_cm")
plt.ylabel("probability")
plt.show()

# %% [markdown]
# #### Looking for Outliers in the column

# %%
fifa_df["height_cm"].quantile(0.10),fifa_df["height_cm"].quantile(0.25),fifa_df["height_cm"].quantile(0.50),fifa_df["height_cm"].quantile(0.75),fifa_df["height_cm"].quantile(0.90)
# Out:
# (173.0, 177.0, 181.0, 186.0, 190.0)

# %%
sns.boxplot(fifa_df["height_cm"],orient="h",color="red")

plt.title("Box plot for height_cm",y=1.02)
plt.xlabel("height_cm")
plt.show()

# %%
sns.violinplot(fifa_df["height_cm"],orient="h",color="beige")

plt.title("Violin plot for height_cm",y=1.02)
plt.xlabel("height_cm")
plt.show()

# %% [markdown]
# #### Conclusion:
#
# **height_cm** has a symmetrical distribution i.e., it is not skewed and has a skewness value of -0.038
#
# * The Density curve of *height_cm* column is centered along mean 181.362 with standard deviation of 6.756.
# * The range of the player's height is from 156 cm to 205 cm.
# * Most of the player's height is in the range from 175 cm to 190 cm.
# * 10% of players are having height of 173 cm and below.
# * 25% of players are having height of 177 cm and below.
# * 50% of players are having height of 181 cm and below.
# * 75% of players are having height of 186 cm and below.
# * 90% of players are having height of 190 cm and below.
# * *height_cm* column is having outliers (i.e., extreme values) towards both lower and higher sides.
#
# **height_cm** column can be further explored with other columns

# %% [markdown]
# ### Exploring *"weight_kg"* column

# %%
fifa_df["weight_kg"].mean()
# Out:
# 75.2763431447642

# %%
fifa_df["weight_kg"].min()
# Out:
# 50

# %%
fifa_df["weight_kg"].max()
# Out:
# 110

# %%
fifa_df["weight_kg"].median()
# Out:
# 75.0

# %%
fifa_df["weight_kg"].std()
# Out:
# 7.047743570355224

# %%
fifa_df["weight_kg"].var()
# Out:
# 49.670689433483396

# %%
fifa_df["weight_kg"].skew()
# Out:
# 0.22080235007640786

# %% [markdown]
# #### Looking at the Distribution of column

# %%
sns.histplot(fifa_df["weight_kg"],color="ivory")

plt.title("Histogram plot of weight_kg",y=1.02)
plt.xlabel("weight_kg")
plt.ylabel("frequency")
plt.show()

# %%
sns.displot(fifa_df["weight_kg"],kind="kde",color="salmon")

plt.title("Density plot of weight_kg",y=1.02)
plt.xlabel("weight_kg")
plt.ylabel("probability")
plt.show()

# %% [markdown]
# #### Looking for Outliers in the column

# %%
fifa_df["weight_kg"].quantile(0.10),fifa_df["weight_kg"].quantile(0.25),fifa_df["weight_kg"].quantile(0.50),fifa_df["weight_kg"].quantile(0.75),fifa_df["weight_kg"].quantile(0.90)
# Out:
# (66.0, 70.0, 75.0, 80.0, 85.0)

# %%
sns.boxplot(fifa_df["weight_kg"],orient="h",color="khaki")

plt.title("Box plot for weight_kg",y=1.02)
plt.xlabel("weight_kg")
plt.show()

# %%
sns.violinplot(fifa_df["weight_kg"],orient="h",color="sienna")

plt.title("Violin plot for weight_kg",y=1.02)
plt.xlabel("weight_kg")
plt.show()

# %% [markdown]
# #### Conclusion:
#
# **weight_kg** has a symmetrical distribution i.e., it is not skewed and has a skewness value of 0.221
#
# * The Density curve of *weight_kg* column is centered along mean 75.276 with standard deviation of 7.047.
# * The range of the player's weight is from 50 kg to 110 kg.
# * Most of the player's weight is in the range from 70 kg to 80 kg.
# * 10% of players are having weight of 66 kg and below.
# * 25% of players are having weight of 70 kg and below.
# * 50% of players are having weight of 75 kg and below.
# * 75% of players are having weight of 80 kg and below.
# * 90% of players are having weight of 85 kg and below.
# * *weight_kg* column is having outliers (i.e., extreme values) towards both lower and higher sides.
#
# **weight_kg** column can be further explored with other columns

# %% [markdown]
# ### Exploring *"nationality"* column

# %%
fifa_df["nationality"].nunique()
# Out:
# 162

# %%
fifa_df["nationality"].unique()
# Out:
# array(['Argentina', 'Portugal', 'Brazil', 'Slovenia', 'Belgium',
#        'Germany', 'Netherlands', 'Croatia', 'Egypt', 'France', 'Senegal',
#        'England', 'Spain', 'Italy', 'Uruguay', 'Poland', 'Denmark',
#        'Gabon', 'Korea Republic', 'Costa Rica', 'Slovakia',
#        'Bosnia Herzegovina', 'Serbia', 'Scotland', 'Hungary',
#        'Switzerland', 'Greece', 'Austria', 'Morocco', 'Sweden', 'Wales',
#        'Colombia', 'Czech Republic', 'Chile', 'Algeria', 'Ivory Coast',
#        'Togo', 'Norway', 'Mexico', 'Iceland', 'Finland', 'Jamaica',
#        'Albania', 'Guinea', 'Cameroon', 'Ghana', 'Montenegro', 'Ukraine',
#        'Russia', 'DR Congo', 'Central African Rep.', 'Venezuela',
#        'Nigeria', 'Armenia', 'Israel', 'Ecuador', 'Paraguay', 'Australia',
#        'Turkey', 'Romania', 'Japan', 'Mali', 'United States', 'Kosovo',
#        'Dominican Republic', 'Tanzania', 'China PR', 'Northern Ireland',
# ...

# %%
fifa_df["nationality"].value_counts()
# Out:
# England                1667
# Germany                1216
# Spain                  1035
# France                  984
# Argentina               886
#                        ...
# Liberia                   1
# São Tomé & Príncipe       1
# Puerto Rico               1
# Bahrain                   1
# Indonesia                 1
# Name: nationality, Length: 162, dtype: int64

# %%
fifa_df["nationality"].value_counts(normalize=True)*100
# Out:
# England                9.120254
# Germany                6.652807
# Spain                  5.662545
# France                 5.383521
# Argentina              4.847357
#                          ...
# Liberia                0.005471
# São Tomé & Príncipe    0.005471
# Puerto Rico            0.005471
# Bahrain                0.005471
# Indonesia              0.005471
# Name: nationality, Length: 162, dtype: float64

# %%
fifa_df["nationality"].value_counts()[:8]
# Out:
# England      1667
# Germany      1216
# Spain        1035
# France        984
# Argentina     886
# Brazil        824
# Italy         732
# Colombia      591
# Name: nationality, dtype: int64

# %%
plt.bar(list(fifa_df["nationality"].value_counts()[:8].keys()),list(fifa_df["nationality"].value_counts()[:8]))

plt.title("Bar plot of nationality",y=1.02)
plt.xlabel("nationality")
plt.ylabel("count")
plt.show()

# %% [markdown]
# #### Conclusion:
#
# * The players are from 162 different nationalities.
# * There are 8 nationalities from which more than 500 players were participating. They are England, Germany, Spain, France, Argentina, Brazil, Italy and Colombia.

# %% [markdown]
# ### Exploring *"club"* column

# %%
fifa_df["club"].nunique()
# Out:
# 698

# %%
fifa_df["club"].unique()
# Out:
# array(['FC Barcelona', 'Juventus', 'Paris Saint-Germain',
#        'Atlético Madrid', 'Real Madrid', 'Manchester City', 'Liverpool',
#        'Napoli', 'Tottenham Hotspur', 'Manchester United', 'Chelsea',
#        'FC Bayern München', 'Inter', 'Borussia Dortmund', 'Arsenal',
#        'Valencia CF', 'Lazio', 'Milan', 'Sporting CP',
#        'Olympique Lyonnais', 'RB Leipzig', 'Ajax', 'LA Galaxy',
#        'Atalanta', 'RC Celta', 'Bayer 04 Leverkusen', 'Real Betis',
#        'FC Porto', 'SV Werder Bremen', 'West Ham United',
#        'Wolverhampton Wanderers', 'AS Saint-Étienne', 'Torino',
#        'Dalian YiFang FC', 'Borussia Mönchengladbach', 'Roma',
#        'Guangzhou Evergrande Taobao FC', 'SL Benfica',
#        'Medipol Başakşehir FK', 'Everton', 'VfL Wolfsburg',
#        'Crystal Palace', 'Getafe CF', 'Shanghai SIPG FC',
#        'Eintracht Frankfurt', 'Olympique de Marseille', 'Hertha BSC',
#        'RSC Anderlecht', 'Villarreal CF', 'Sampdoria', 'Leicester City',
# ...

# %%
fifa_df["club"].value_counts()
# Out:
# FC Barcelona                  33
# Real Valladolid CF            33
# VfL Wolfsburg                 33
# Crystal Palace                33
# Eintracht Frankfurt           33
#                               ..
# US Orléans Loiret Football     1
# Canada                         1
# Mexico                         1
# Turkey                         1
# Śląsk Wrocław                  1
# Name: club, Length: 698, dtype: int64

# %% [markdown]
# #### Conclusion:
#
# * There are 698 different clubs.
# * The number of players each club is having is in the range from 1 to 33.

# %% [markdown]
# ### Exploring *"overall"* column

# %%
fifa_df["overall"].mean()
# Out:
# 66.24499398183609

# %%
fifa_df["overall"].min()
# Out:
# 48

# %%
fifa_df["overall"].max()
# Out:
# 94

# %%
fifa_df["overall"].median()
# Out:
# 66.0

# %%
fifa_df["overall"].std()
# Out:
# 6.949953254963321

# %%
fifa_df["overall"].var()
# Out:
# 48.30185024617526

# %%
fifa_df["overall"].skew()
# Out:
# 0.07089343291701235

# %% [markdown]
# #### Looking at the Distribution of column

# %%
sns.histplot(fifa_df["overall"],color="blue")

plt.title("Histogram plot of overall rating",y=1.02)
plt.xlabel("overall rating")
plt.ylabel("frequency")
plt.show()

# %%
sns.displot(fifa_df["overall"],kind="kde",color="brown")

plt.title("Density plot of overall rating",y=1.02)
plt.xlabel("overall rating")
plt.ylabel("probability")
plt.show()

# %% [markdown]
# #### Looking for Outliers in the column

# %%
fifa_df["overall"].quantile(0.10),fifa_df["overall"].quantile(0.25),fifa_df["overall"].quantile(0.50),fifa_df["overall"].quantile(0.75),fifa_df["overall"].quantile(0.90)
# Out:
# (57.0, 62.0, 66.0, 71.0, 75.0)

# %%
sns.boxplot(fifa_df["overall"],orient="h",color="lavender")

plt.title("Box plot for overall rating",y=1.02)
plt.xlabel("overall rating")
plt.show()

# %%
sns.violinplot(fifa_df["overall"],orient="h",color="silver")

plt.title("Violin plot for overall rating",y=1.02)
plt.xlabel("overall rating")
plt.show()

# %% [markdown]
# #### Conclusion:
#
# **overall** has a symmetrical distribution i.e., it is not skewed and has a skewness value of 0.071
#
# * The Density curve of column is centered along mean 66.245 with standard deviation of 6.949.
# * The range of values is from 48 to 94.
# * Most of the players have an overall rating in the range from 60 to 75.
# * 10% of the players have an overall rating of 57 or below.
# * 25% of the players have an overall rating of 62 or below.
# * 50% of the players have an overall rating of 66 or below.
# * 75% of the players have an overall rating of 71 or below.
# * 90% of the players have an overall rating of 75 or below.
# * *overall* column is having outliers (i.e., extreme values) towards lower and higher sides.

# %% [markdown]
# ### Exploring *"potential"* column

# %%
fifa_df["potential"].mean()
# Out:
# 71.5468869679396

# %%
fifa_df["potential"].min()
# Out:
# 49

# %%
fifa_df["potential"].max()
# Out:
# 95

# %%
fifa_df["potential"].median()
# Out:
# 71.0

# %%
fifa_df["potential"].std()
# Out:
# 6.139669074956248

# %%
fifa_df["potential"].var()
# Out:
# 37.69553634997411

# %%
fifa_df["potential"].skew()
# Out:
# 0.24994078132804365

# %% [markdown]
# #### Looking at the Distribution of column

# %%
sns.histplot(fifa_df["potential"],color="lightblue")

plt.title("Histogram plot of potential",y=1.02)
plt.xlabel("potential")
plt.ylabel("frequency")
plt.show()

# %%
sns.displot(fifa_df["potential"],kind="kde",color="tan")

plt.title("Density plot of potential",y=1.02)
plt.xlabel("potential")
plt.ylabel("probability")
plt.show()

# %% [markdown]
# #### Looking for Outliers in the column

# %%
fifa_df["potential"].quantile(0.10),fifa_df["potential"].quantile(0.25),fifa_df["potential"].quantile(0.50),fifa_df["potential"].quantile(0.75),fifa_df["potential"].quantile(0.90)
# Out:
# (64.0, 67.0, 71.0, 75.0, 80.0)

# %%
sns.boxplot(fifa_df["potential"],orient="h",color="chocolate")

plt.title("Box plot for potential",y=1.02)
plt.xlabel("potential")
plt.show()

# %%
sns.violinplot(fifa_df["potential"],orient="h",color="lime")

plt.title("Violin plot for potential",y=1.02)
plt.xlabel("potential")
plt.show()

# %% [markdown]
# #### Conclusion:
#
# **potential** has a symmetrical distribution i.e., it is not skewed and has a skewness value of 0.249
#
# * The Density curve of column is centered along mean 71.547 with standard deviation of 6.139.
# * The range of values is from 49 to 95.
# * Most of the players are having potential in the range from 65 to 80.
# * 10% of the players are having a potential of 64 or below.
# * 25% of the players are having a potential of 67 or below.
# * 50% of the players are having a potential of 71 or below.
# * 75% of the players are having a potential of 75 or below.
# * 90% of the players are having a potential of 80 or below.
# * *potential* column is having outliers (i.e., extreme values) towards lower and higher sides.

# %% [markdown]
# ### Exploring *"value_eur"* column

# %%
fifa_df["value_eur"].mean()
# Out:
# 2484037.640879746

# %%
fifa_df["value_eur"].min()
# Out:
# 0

# %%
fifa_df["value_eur"].max()
# Out:
# 105500000

# %%
fifa_df["value_eur"].median()
# Out:
# 700000.0

# %%
fifa_df["value_eur"].std()
# Out:
# 5585481.06147366

# %%
fifa_df["value_eur"].var()
# Out:
# 31197598688080.926

# %%
fifa_df["value_eur"].skew()
# Out:
# 6.425940918096741

# %% [markdown]
# #### Looking at the Distribution of column

# %%
sns.histplot(fifa_df["value_eur"],color="chartreuse")

plt.title("Histogram plot of value_eur",y=1.02)
plt.xlabel("value_eur")
plt.ylabel("frequency")
plt.show()

# %%
sns.displot(fifa_df["value_eur"],kind="kde",color="lightgreen")

plt.title("Density plot of value_eur",y=1.02)
plt.xlabel("value_eur")
plt.ylabel("probability")
plt.show()

# %% [markdown]
# #### Looking for Outliers in the column

# %%
fifa_df["value_eur"].quantile(0.10),fifa_df["value_eur"].quantile(0.25),fifa_df["value_eur"].quantile(0.50),fifa_df["value_eur"].quantile(0.75),fifa_df["value_eur"].quantile(0.90)
# Out:
# (140000.0, 325000.0, 700000.0, 2100000.0, 6500000.0)

# %%
sns.boxplot(fifa_df["value_eur"],orient="h",color="teal")

plt.title("Box plot for value_eur",y=1.02)
plt.xlabel("value_eur")
plt.show()

# %%
sns.violinplot(fifa_df["value_eur"],orient="h",color="tomato")

plt.title("Violin plot for value_eur",y=1.02)
plt.xlabel("value_eur")
plt.show()

# %% [markdown]
# #### Conclusion:
#
# **value_eur** has an asymmetrical distribution i.e., it is skewed with a skewness value of 6.425
#
# * The Density curve of column is centered along mean 2484037.64 with standard deviation of 5585481.06.
# * The range of values is from 0 to 105500000.
# * Most of the players have value in the range from 0 to 5000000 eur.
# * 10% of the players have value of 140000 eur and below.
# * 25% of the players have value of 325000 eur and below.
# * 50% of the players have value of 700000 eur and below.
# * 75% of the players have value of 2100000 eur and below.
# * 90% of the players have value of 6500000 eur and below.
# * *value_eur* column is having outliers (i.e., extreme values) towards higher side.

# %% [markdown]
# ### Exploring *"wage_eur"* column

# %%
fifa_df["wage_eur"].mean()
# Out:
# 9456.942772732247

# %%
fifa_df["wage_eur"].min()
# Out:
# 0

# %%
fifa_df["wage_eur"].max()
# Out:
# 565000

# %%
fifa_df["wage_eur"].median()
# Out:
# 3000.0

# %%
fifa_df["wage_eur"].std()
# Out:
# 21351.7140952595

# %%
fifa_df["wage_eur"].var()
# Out:
# 455895694.8057032

# %%
fifa_df["wage_eur"].skew()
# Out:
# 7.821095907798625

# %% [markdown]
# #### Looking at the Distribution of column

# %%
sns.histplot(fifa_df["wage_eur"],color="coral")

plt.title("Histogram plot of wage_eur",y=1.02)
plt.xlabel("wage_eur")
plt.ylabel("frequency")
plt.show()

# %%
sns.displot(fifa_df["wage_eur"],kind="kde",color="magenta")

plt.title("Density plot of wage_eur",y=1.02)
plt.xlabel("wage_eur")
plt.ylabel("probability")
plt.show()

# %% [markdown]
# #### Looking for Outliers in the column

# %%
fifa_df["wage_eur"].quantile(0.10),fifa_df["wage_eur"].quantile(0.25),fifa_df["wage_eur"].quantile(0.50),fifa_df["wage_eur"].quantile(0.75),fifa_df["wage_eur"].quantile(0.90)
# Out:
# (1000.0, 1000.0, 3000.0, 8000.0, 23000.0)

# %%
sns.boxplot(fifa_df["wage_eur"],orient="h",color="turquoise")

plt.title("Box plot for wage_eur",y=1.02)
plt.xlabel("wage_eur")
plt.show()

# %%
sns.violinplot(fifa_df["wage_eur"],orient="h",color="crimson")

plt.title("Violin plot for wage_eur",y=1.02)
plt.xlabel("wage_eur")
plt.show()

# %% [markdown]
# #### Conclusion:
#
# **wage_eur** has an asymmetrical distribution i.e., it is skewed with a skewness value of 7.821
#
# * The Density curve of column is centered along mean 9456.942 with standard deviation of 21351.714.
# * The range of values is from 0 to 565000.
# * Most of the players have wages in the range from 0 to 30000 eur.
# * 25% of the players have wage of 1000 eur and below.
# * 50% of the players have wage of 3000 eur and below.
# * 75% of the players have wage of 8000 eur and below.
# * 90% of the players have wage of 23000 eur and below.
# * *wage_eur* column is having outliers (i.e., extreme values) towards higher side.

# %% [markdown]
# ### Exploring *"preferred_foot"* column

# %%
fifa_df["preferred_foot"].nunique()
# Out:
# 2

# %%
fifa_df["preferred_foot"].unique()
# Out:
# array(['Left', 'Right'], dtype=object)

# %%
fifa_df["preferred_foot"].value_counts()
# Out:
# Right    13960
# Left      4318
# Name: preferred_foot, dtype: int64

# %%
fifa_df["preferred_foot"].value_counts(normalize=True)*100
# Out:
# Right    76.375971
# Left     23.624029
# Name: preferred_foot, dtype: float64

# %%
sns.countplot(x=fifa_df["preferred_foot"])

plt.title("Count plot for preferred_foot",y=1.02)
plt.xlabel("preferred_foot")
plt.show()

# %%
sizes = [13960,4318]

plt.pie(sizes,labels=["Right","Left"],autopct="%1.1f%%")
plt.title("Pie chart for preferred_foot",y=1.02)
plt.legend()
plt.show()

# %% [markdown]
# #### Conclusion:
#
# Most of the players i.e., 76.4% of total players prefer right foot for hitting the ball, and the rest i.e., 23.6% prefer left foot.

# %% [markdown]
# ### Exploring different columns in conjunction

# %%
oldest_players = fifa_df[["short_name","age"]].sort_values(by=["age"],ascending=False)

# %%
oldest_players[:10]
# Out:
#          short_name  age
# 13003  H. Sulaimani   42
# 11832      C. Muñoz   42
# 200       G. Buffon   41
# 3706   C. Lucchetti   41
# 10665      F. Kippe   41
# 868          Hilton   41
# 2965      Cifuentes   40
# 15812     M. Gurski   40
# 8359      F. Cubero   40
# 2963    D. Dainelli   40

# %%
plt.figure(figsize=(10,5))
plt.bar(list(oldest_players["short_name"])[:10],list(oldest_players["age"])[:10])

plt.title("Bar plot of oldest players",y=1.02)
plt.xlabel("name")
plt.ylabel("age")
plt.show()

# %%
youngest_players = fifa_df[["short_name","age"]].sort_values(by=["age"],ascending=True)

# %%
youngest_players[:10]
# Out:
#           short_name  age
# 18171    J. Starbuck   16
# 4764       A. Hložek   16
# 18243   E. Sartorius   16
# 17827       D. Burns   16
# 17614    D. Obbekjær   16
# 17782    S. Anderson   16
# 18242     R. Wikberg   16
# 18031  O. Stefánsson   16
# 14626     A. Velasco   16
# 12160    S. Esposito   16

# %%
plt.figure(figsize=(12,5))
plt.bar(list(youngest_players["short_name"])[:10],list(youngest_players["age"])[:10],color="orange")

plt.title("Bar plot of youngest players",y=1.02)
plt.xlabel("name")
plt.ylabel("age")
plt.show()

# %%
tallest_players = fifa_df[["short_name","height_cm"]].sort_values(by=["height_cm"],ascending=False)

# %%
tallest_players[:10]
# Out:
#                 short_name  height_cm
# 9208               T. Holý        205
# 8200                 A. Ba        203
# 12808           A. Chapman        203
# 3121         C. Pantilimon        203
# 12864             M. Qvist        203
# 17365             M. Casey        203
# 5451             L. Traoré        203
# 17149            S. Brolin        202
# 4868   V. Milinković-Savić        202
# 7725           K. Scherpen        202

# %%
plt.figure(figsize=(12,5))
plt.bar(list(tallest_players["short_name"])[:10],list(tallest_players["height_cm"])[:10],color="red")

plt.title("Bar plot of tallest players",y=1.02)
plt.xlabel("name")
plt.ylabel("height_cm")
plt.show()

# %%
weight_of_tall_players = fifa_df[["short_name","height_cm","weight_kg"]].sort_values(by=["height_cm"],ascending=False)

# %%
weight_of_tall_players[:10]
# Out:
#                 short_name  height_cm  weight_kg
# 9208               T. Holý        205        102
# 8200                 A. Ba        203         94
# 12808           A. Chapman        203         92
# 3121         C. Pantilimon        203         96
# 12864             M. Qvist        203         94
# 17365             M. Casey        203         80
# 5451             L. Traoré        203         87
# 17149            S. Brolin        202         85
# 4868   V. Milinković-Savić        202         92
# 7725           K. Scherpen        202         85

# %%
plt.figure(figsize=(12,5))
plt.bar(list(weight_of_tall_players["short_name"])[:10],list(weight_of_tall_players["weight_kg"])[:10],color="aqua")

plt.title("Bar plot of weight of tall players",y=1.02)
plt.xlabel("name")
plt.ylabel("weight_kg")
plt.show()

# %%
highest_valued_players = fifa_df[["short_name","value_eur"]].sort_values(by=["value_eur"],ascending=False)

# %%
highest_valued_players[:10]
# Out:
#       short_name  value_eur
# 2      Neymar Jr  105500000
# 0       L. Messi   95500000
# 10     K. Mbappé   93500000
# 5   K. De Bruyne   90000000
# 4      E. Hazard   90000000
# 12       H. Kane   83000000
# 9       M. Salah   80500000
# 7    V. van Dijk   78000000
# 3       J. Oblak   77500000
# 23     P. Dybala   76500000

# %%
plt.figure(figsize=(12,5))
plt.bar(list(highest_valued_players["short_name"])[:10],list(highest_valued_players["value_eur"])[:10],color="green")

plt.title("Bar plot of highest valued players",y=1.02)
plt.xlabel("name")
plt.ylabel("value_eur")
plt.show()

# %%
highest_waged_players = fifa_df[["short_name","wage_eur"]].sort_values(by=["wage_eur"],ascending=False)

# %%
highest_waged_players[:10]
# Out:
#            short_name  wage_eur
# 0            L. Messi    565000
# 4           E. Hazard    470000
# 1   Cristiano Ronaldo    405000
# 5        K. De Bruyne    370000
# 22       A. Griezmann    370000
# 19          L. Suárez    355000
# 8           L. Modrić    340000
# 36           T. Kroos    330000
# 17          S. Agüero    300000
# 21    Sergio Busquets    300000

# %%
plt.figure(figsize=(12,5))
plt.bar(list(highest_waged_players["short_name"])[:10],list(highest_waged_players["wage_eur"])[:10],color="plum")

plt.title("Bar plot of highest waged players",y=1.02)
plt.xlabel("name")
plt.ylabel("wage_eur")
plt.show()

# %%
high_paced_players = fifa_df[["short_name","pace"]].sort_values(by=["pace"],ascending=False)

# %%
high_paced_players[:10]
# Out:
#           short_name  pace
# 2167    Adama Traoré  96.0
# 10         K. Mbappé  96.0
# 6495        K. Nagai  95.0
# 9065        A. Chalá  95.0
# 55           L. Sané  95.0
# 256   Gelson Martins  95.0
# 2548    L. Advíncula  94.0
# 6852       K. Manneh  94.0
# 150    Douglas Costa  94.0
# 38     P. Aubameyang  94.0

# %%
plt.figure(figsize=(12,5))
plt.bar(list(high_paced_players["short_name"])[:10],list(high_paced_players["pace"])[:10],color="aquamarine")

plt.title("Bar plot of players with high pace",y=1.02)
plt.xlabel("name")
plt.ylabel("pace")
plt.show()

# %%
shooting = fifa_df[["short_name","shooting"]].sort_values(by=["shooting"],ascending=False)

# %%
shooting[:10]
# Out:
#             short_name  shooting
# 1    Cristiano Ronaldo      93.0
# 0             L. Messi      92.0
# 12             H. Kane      91.0
# 17           S. Agüero      90.0
# 205    F. Quagliarella      89.0
# 19           L. Suárez      89.0
# 96      Z. Ibrahimović      88.0
# 37             M. Reus      88.0
# 100            G. Bale      87.0
# 20      R. Lewandowski      87.0

# %%
plt.figure(figsize=(12,5))
plt.bar(list(shooting["short_name"])[:10],list(shooting["shooting"])[:10],color="grey")

plt.title("Bar plot of players with good shooting skills",y=1.02)
plt.xlabel("name")
plt.ylabel("shooting")
plt.show()

# %%
passing = fifa_df[["short_name","passing"]].sort_values(by=["passing"],ascending=False)

# %%
passing[:10]
# Out:
#         short_name  passing
# 0         L. Messi     92.0
# 5     K. De Bruyne     92.0
# 27      C. Eriksen     90.0
# 36        T. Kroos     90.0
# 8        L. Modrić     89.0
# 69          Parejo     88.0
# 33     David Silva     88.0
# 375  Cesc Fàbregas     87.0
# 65       M. Pjanić     87.0
# 106   J. Rodríguez     87.0

# %%
plt.figure(figsize=(12,5))
plt.bar(list(passing["short_name"])[:10],list(passing["passing"])[:10],color="purple")

plt.title("Bar plot of players with good passing skills",y=1.02)
plt.xlabel("name")
plt.ylabel("passing")
plt.show()

# %%
dribbling = fifa_df[["short_name","dribbling"]].sort_values(by=["dribbling"],ascending=False)

# %%
dribbling[:10]
# Out:
#          short_name  dribbling
# 0          L. Messi       96.0
# 2         Neymar Jr       95.0
# 4         E. Hazard       94.0
# 41   Bernardo Silva       92.0
# 150   Douglas Costa       91.0
# 62             Isco       91.0
# 48       D. Mertens       91.0
# 54       L. Insigne       91.0
# 23        P. Dybala       90.0
# 58      M. Verratti       90.0

# %%
plt.figure(figsize=(12,5))
plt.bar(list(dribbling["short_name"])[:10],list(dribbling["dribbling"])[:10],color="indigo")

plt.title("Bar plot of players with good dribbling skills",y=1.02)
plt.xlabel("name")
plt.ylabel("dribbling")
plt.show()

# %%
defending = fifa_df[["short_name","defending"]].sort_values(by=["defending"],ascending=False)

# %%
defending[:10]
# Out:
#          short_name  defending
# 16     G. Chiellini       90.0
# 7       V. van Dijk       90.0
# 11     K. Koulibaly       89.0
# 35         D. Godín       89.0
# 49       M. Hummels       89.0
# 29            Piqué       88.0
# 50  T. Alderweireld       88.0
# 40       A. Laporte       88.0
# 47    J. Vertonghen       87.0
# 67       L. Bonucci       87.0

# %%
plt.figure(figsize=(12,5))
plt.bar(list(defending["short_name"])[:10],list(defending["defending"])[:10],color="salmon")

plt.title("Bar plot of players with good defending skills",y=1.02)
plt.xlabel("name")
plt.ylabel("defending")
plt.show()

# %%
physic = fifa_df[["short_name","physic"]].sort_values(by=["physic"],ascending=False)

# %%
physic[:10]
# Out:
#          short_name  physic
# 562       M. Marega    90.0
# 4026        Garrido    89.0
# 42         Casemiro    89.0
# 389      M. Sissoko    89.0
# 600          Wesley    88.0
# 7293    M. Bostwick    88.0
# 10486       A. Coly    88.0
# 1196       J. Kucka    88.0
# 7515      B. Fofana    88.0
# 345    G. Kondogbia    88.0

# %%
plt.figure(figsize=(12,5))
plt.bar(list(physic["short_name"])[:10],list(physic["physic"])[:10],color="khaki")

plt.title("Bar plot of players with good physic",y=1.02)
plt.xlabel("name")
plt.ylabel("physic")
plt.show()

# %%
gk_diving = fifa_df[["short_name","gk_diving"]].sort_values(by=["gk_diving"],ascending=False)

# %%
gk_diving[:10]
# Out:
#        short_name  gk_diving
# 14         De Gea       90.0
# 53       K. Navas       90.0
# 74  G. Donnarumma       90.0
# 32      H. Lloris       89.0
# 30  S. Handanovič       88.0
# 6   M. ter Stegen       88.0
# 3        J. Oblak       87.0
# 31       M. Neuer       87.0
# 86       A. Lopes       87.0
# 91           Neto       86.0

# %%
plt.figure(figsize=(12,5))
plt.bar(list(gk_diving["short_name"])[:10],list(gk_diving["gk_diving"])[:10],color="sienna")

plt.title("Bar plot of goal keepers with good diving skills",y=1.02)
plt.xlabel("name")
plt.ylabel("gk_diving")
plt.show()

# %%
gk_handling = fifa_df[["short_name","gk_handling"]].sort_values(by=["gk_handling"],ascending=False)

# %%
gk_handling[:10]
# Out:
#            short_name  gk_handling
# 3            J. Oblak         92.0
# 28        T. Courtois         89.0
# 31           M. Neuer         87.0
# 87         P. Gulácsi         86.0
# 137         Y. Sommer         85.0
# 6       M. ter Stegen         85.0
# 30      S. Handanovič         85.0
# 130        S. Ruffier         84.0
# 294        E. Viviano         84.0
# 324  Raphaelito Anjos         84.0

# %%
plt.figure(figsize=(12,5))
plt.bar(list(gk_handling["short_name"])[:10],list(gk_handling["gk_handling"])[:10],color="lavender")

plt.title("Bar plot of goal keepers with good handling skills",y=1.02)
plt.xlabel("name")
plt.ylabel("gk_handling")
plt.show()

# %%
gk_kicking = fifa_df[["short_name","gk_kicking"]].sort_values(by=["gk_kicking"],ascending=False)

# %%
gk_kicking[:10]
# Out:
#           short_name  gk_kicking
# 25           Ederson        93.0
# 31          M. Neuer        91.0
# 875         I. Khune        90.0
# 6      M. ter Stegen        88.0
# 181      J. Pickford        87.0
# 248         A. Onana        86.0
# 111             Kepa        86.0
# 2762  M. Pigliacelli        85.0
# 13           Alisson        85.0
# 1786    P. Gazzaniga        84.0

# %%
plt.figure(figsize=(12,5))
plt.bar(list(gk_kicking["short_name"])[:10],list(gk_kicking["gk_kicking"])[:10],color="silver")

plt.title("Bar plot of goal keepers with good kicking skills",y=1.02)
plt.xlabel("name")
plt.ylabel("gk_kicking")
plt.show()

# %%
gk_reflexes = fifa_df[["short_name","gk_reflexes"]].sort_values(by=["gk_reflexes"],ascending=False)

# %%
gk_reflexes[:10]
# Out:
#        short_name  gk_reflexes
# 14         De Gea         92.0
# 32      H. Lloris         91.0
# 53       K. Navas         90.0
# 6   M. ter Stegen         90.0
# 74  G. Donnarumma         90.0
# 88       R. Bürki         89.0
# 86       A. Lopes         89.0
# 3        J. Oblak         89.0
# 30  S. Handanovič         89.0
# 13        Alisson         89.0

# %%
plt.figure(figsize=(12,5))
plt.bar(list(gk_reflexes["short_name"])[:10],list(gk_reflexes["gk_reflexes"])[:10],color="lightblue")

plt.title("Bar plot of goal keepers with good reflexes",y=1.02)
plt.xlabel("name")
plt.ylabel("gk_reflexes")
plt.show()

# %%
gk_speed = fifa_df[["short_name","gk_speed"]].sort_values(by=["gk_speed"],ascending=False)

# %%
gk_speed[:10]
# Out:
#           short_name  gk_speed
# 2746      R. Zentner      65.0
# 364      Jordi Masip      65.0
# 86          A. Lopes      64.0
# 1786    P. Gazzaniga      64.0
# 25           Ederson      63.0
# 11533  A. Maisonnial      63.0
# 15115   J. Rodríguez      63.0
# 248         A. Onana      63.0
# 3792         Alberto      63.0
# 32         H. Lloris      63.0

# %%
plt.figure(figsize=(12,5))
plt.bar(list(gk_speed["short_name"])[:10],list(gk_speed["gk_speed"])[:10],color="tan")

plt.title("Bar plot of goal keepers with good speed",y=1.02)
plt.xlabel("name")
plt.ylabel("gk_speed")
plt.show()

# %%
sns.scatterplot(data=fifa_df, x="height_cm", y="weight_kg")

plt.title("Scatter plot for height and weight",y=1.02)
plt.show()

# %% [markdown]
# #### Conclusion:
#
# * Different columns have been explored.
# * Players with highest age, height, most valued, high wage, high pace, good shooting skills, good passing skills, good dribbling skills, good defending skills and good physic have been explored.
# * Goal keepers with good diving skills, good handling skills, good kicking skills, good reflexes and high speed have been explored.

# %% [markdown]
# ### Plotting Heat Map

# %%
data = fifa_df[['age','height_cm','weight_kg','overall','potential','value_eur','wage_eur']].corr()

# %%
plt.figure(figsize=(10,6))
sns.heatmap(data,cmap="viridis",annot=True,linewidth=.5)

plt.title("Heat Map",y=1.02)
plt.show()

# %% [markdown]
# #### Conclusion:
#
# * The correlation between the columns has been explored.

# %% [markdown]
# # Data Wrangling

# %% [markdown]
# ### Handling duplicate data

# %%
fifa_df.shape
# Out:
# (18278, 104)

# %%
fifa_df.drop_duplicates().shape
# Out:
# (18278, 104)

# %%
fifa_df
# Out:
#        sofifa_id                                         player_url  \
# 0         158023  https://sofifa.com/player/158023/lionel-messi/...
# 1          20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2         190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3         200389  https://sofifa.com/player/200389/jan-oblak/20/...
# 4         183277  https://sofifa.com/player/183277/eden-hazard/2...
# ...          ...                                                ...
# 18273     245006  https://sofifa.com/player/245006/shuai-shao/20...
# 18274     250995  https://sofifa.com/player/250995/mingjie-xiao/...
# 18275     252332  https://sofifa.com/player/252332/wei-zhang/20/...
# 18276     251110  https://sofifa.com/player/251110/haijian-wang/...
# 18277     233449  https://sofifa.com/player/233449/ximing-pan/20...
#
#               short_name                            long_name  age  \
# 0               L. Messi       Lionel Andrés Messi Cuccittini   32
# ...

# %% [markdown]
# #### Insights:
#
# It is identified that there are no duplicate rows in the data.

# %% [markdown]
# ### Removing unneccessary columns

# %%
fifa_df.drop(columns=['player_url','short_name','long_name','dob','player_positions','work_rate','body_type','real_face','player_tags','team_position','team_jersey_number','loaned_from','joined','nation_position','nation_jersey_number','player_traits','ls','st','rs','lw','lf','cf','rf','rw','lam','cam','ram','lm','lcm','cm','rcm','rm','lwb','ldm','cdm','rdm','rwb','lb','lcb','cb','rcb','rb'],inplace=True,axis=1)
fifa_df.head()
# Out:
#    sofifa_id  age  height_cm  weight_kg nationality                 club  \
# 0     158023   32        170         72   Argentina         FC Barcelona
# 1      20801   34        187         83    Portugal             Juventus
# 2     190871   27        175         68      Brazil  Paris Saint-Germain
# 3     200389   26        188         87    Slovenia      Atlético Madrid
# 4     183277   28        175         74     Belgium          Real Madrid
#
#    overall  potential  value_eur  wage_eur  ... mentality_penalties  \
# 0       94         94   95500000    565000  ...                  75
# 1       93         93   58500000    405000  ...                  85
# 2       92         92  105500000    290000  ...                  90
# 3       91         93   77500000    125000  ...                  11
# 4       91         91   90000000    470000  ...                  88
#
#    mentality_composure  defending_marking  defending_standing_tackle  \
# ...

# %% [markdown]
# #### Insights:
#
# Unneccessary columns have been removed from the dataset.

# %% [markdown]
# ### Checking null values

# %%
fifa_df.isnull().sum()
# Out:
# sofifa_id                  0
# age                        0
# height_cm                  0
# weight_kg                  0
# nationality                0
#                           ..
# goalkeeping_diving         0
# goalkeeping_handling       0
# goalkeeping_kicking        0
# goalkeeping_positioning    0
# goalkeeping_reflexes       0
# Length: 62, dtype: int64

# %%
list(fifa_df.isnull()),list(fifa_df.isnull().sum())
# Out:
# (['sofifa_id',
#   'age',
#   'height_cm',
#   'weight_kg',
#   'nationality',
#   'club',
#   'overall',
#   'potential',
#   'value_eur',
#   'wage_eur',
#   'preferred_foot',
#   'international_reputation',
#   'weak_foot',
#   'skill_moves',
#   'release_clause_eur',
#   'contract_valid_until',
#   'pace',
#   'shooting',
#   'passing',
#   'dribbling',
#   'defending',
#   'physic',
#   'gk_diving',
#   'gk_handling',
#   'gk_kicking',
#   'gk_reflexes',
#   'gk_speed',
#   'gk_positioning',
#   'attacking_crossing',
#   'attacking_finishing',
#   'attacking_heading_accuracy',
#   'attacking_short_passing',
#   'attacking_volleys',
#   'skill_dribbling',
#   'skill_curve',
#   'skill_fk_accuracy',
#   'skill_long_passing',
#   'skill_ball_control',
#   'movement_acceleration',
#   'movement_sprint_speed',
#   'movement_agility',
#   'movement_reactions',
#   'movement_balance',
#   'power_shot_power',
#   'power_jumping',
#   'power_stamina',
#   'power_strength',
# ...

# %%
fifa_df.drop(columns=['gk_diving','gk_handling','gk_kicking','gk_reflexes','gk_speed','gk_positioning'],inplace=True,axis=1)
fifa_df.head()
# Out:
#    sofifa_id  age  height_cm  weight_kg nationality                 club  \
# 0     158023   32        170         72   Argentina         FC Barcelona
# 1      20801   34        187         83    Portugal             Juventus
# 2     190871   27        175         68      Brazil  Paris Saint-Germain
# 3     200389   26        188         87    Slovenia      Atlético Madrid
# 4     183277   28        175         74     Belgium          Real Madrid
#
#    overall  potential  value_eur  wage_eur  ... mentality_penalties  \
# 0       94         94   95500000    565000  ...                  75
# 1       93         93   58500000    405000  ...                  85
# 2       92         92  105500000    290000  ...                  90
# 3       91         93   77500000    125000  ...                  11
# 4       91         91   90000000    470000  ...                  88
#
#    mentality_composure  defending_marking  defending_standing_tackle  \
# ...

# %%
fifa_df["release_clause_eur"].fillna(fifa_df["release_clause_eur"].median(),inplace=True)
fifa_df["contract_valid_until"].fillna(fifa_df["contract_valid_until"].median(),inplace=True)
fifa_df["pace"].fillna(fifa_df["pace"].median(),inplace=True)
fifa_df["shooting"].fillna(fifa_df["shooting"].median(),inplace=True)
fifa_df["passing"].fillna(fifa_df["passing"].median(),inplace=True)
fifa_df["dribbling"].fillna(fifa_df["dribbling"].median(),inplace=True)
fifa_df["defending"].fillna(fifa_df["defending"].median(),inplace=True)
fifa_df["physic"].fillna(fifa_df["physic"].median(),inplace=True)

# %%
fifa_df.isnull().sum()
# Out:
# sofifa_id                     0
# age                           0
# height_cm                     0
# weight_kg                     0
# nationality                   0
# club                          0
# overall                       0
# potential                     0
# value_eur                     0
# wage_eur                      0
# preferred_foot                0
# international_reputation      0
# weak_foot                     0
# skill_moves                   0
# release_clause_eur            0
# contract_valid_until          0
# pace                          0
# shooting                      0
# passing                       0
# dribbling                     0
# defending                     0
# physic                        0
# attacking_crossing            0
# attacking_finishing           0
# attacking_heading_accuracy    0
# attacking_short_passing       0
# attacking_volleys             0
# skill_dribbling               0
# skill_curve                   0
# ...

# %%
fifa_df.shape
# Out:
# (18278, 56)

# %% [markdown]
# #### Insights:
#
# * *gk_diving*,*gk_handling*,*gk_kicking*,*gk_reflexes*,*gk_speed*,*gk_positioning* columns have been removed as the missing percentage of data is more than 70.
# * And the null values in the remaining columns are filled using the median of the respective columns by **fillna()** function.

# %% [markdown]
# ### Handling outliers

# %% [markdown]
# #### *age* column

# %%
fifa_df = fifa_df[fifa_df["age"] <= 40]

# %%
fifa_df[fifa_df["age"] > 40]
# Out:
# Empty DataFrame
# Columns: [sofifa_id, age, height_cm, weight_kg, nationality, club, overall, potential, value_eur, wage_eur, preferred_foot, international_reputation, weak_foot, skill_moves, release_clause_eur, contract_valid_until, pace, shooting, passing, dribbling, defending, physic, attacking_crossing, attacking_finishing, attacking_heading_accuracy, attacking_short_passing, attacking_volleys, skill_dribbling, skill_curve, skill_fk_accuracy, skill_long_passing, skill_ball_control, movement_acceleration, movement_sprint_speed, movement_agility, movement_reactions, movement_balance, power_shot_power, power_jumping, power_stamina, power_strength, power_long_shots, mentality_aggression, mentality_interceptions, mentality_positioning, mentality_vision, mentality_penalties, mentality_composure, defending_marking, defending_standing_tackle, defending_sliding_tackle, goalkeeping_diving, goalkeeping_handling, goalkeeping_kicking, goalkeeping_positioning, goalkeeping_reflexes]
# ...

# %% [markdown]
# #### *height_cm* column

# %%
fifa_df = fifa_df[fifa_df["height_cm"] >= 160]

# %% [markdown]
# #### *weight_kg* column

# %%
fifa_df = fifa_df[fifa_df["weight_kg"] <= 100]

# %% [markdown]
# #### *overall* column

# %%
fifa_df = fifa_df[fifa_df["overall"] <= 90]

# %% [markdown]
# #### *potential* column

# %%
fifa_df = fifa_df[fifa_df["potential"] <= 90]

# %% [markdown]
# #### *value_eur* column

# %%
fifa_df = fifa_df[fifa_df["value_eur"] <= 10000000]

# %% [markdown]
# #### *wage_eur* column

# %%
fifa_df = fifa_df[fifa_df["wage_eur"] <= 50000]

# %%
fifa_df
# Out:
#        sofifa_id  age  height_cm  weight_kg nationality  \
# 128       120533   36        188         81    Portugal
# 201         5479   38        185         84       Spain
# 205       159261   36        180         79       Italy
# 208       168609   34        186         78      Brazil
# 286        24630   36        188         92       Spain
# ...          ...  ...        ...        ...         ...
# 18273     245006   22        186         79    China PR
# 18274     250995   22        177         66    China PR
# 18275     252332   19        186         75    China PR
# 18276     251110   18        185         74    China PR
# 18277     233449   26        182         78    China PR
#
#                                 club  overall  potential  value_eur  wage_eur  \
# 128                         FC Porto       84         84    6500000     16000
# 201                         FC Porto       83         83    2600000     11000
# ...

# %%
fifa_df.reset_index(drop=True,inplace=True)
fifa_df
# Out:
#        sofifa_id  age  height_cm  weight_kg nationality  \
# 0         120533   36        188         81    Portugal
# 1           5479   38        185         84       Spain
# 2         159261   36        180         79       Italy
# 3         168609   34        186         78      Brazil
# 4          24630   36        188         92       Spain
# ...          ...  ...        ...        ...         ...
# 17144     245006   22        186         79    China PR
# 17145     250995   22        177         66    China PR
# 17146     252332   19        186         75    China PR
# 17147     251110   18        185         74    China PR
# 17148     233449   26        182         78    China PR
#
#                                 club  overall  potential  value_eur  wage_eur  \
# 0                           FC Porto       84         84    6500000     16000
# 1                           FC Porto       83         83    2600000     11000
# ...

# %% [markdown]
# #### Insights:
#
# The outliers have been handled in the respective columns by applying filtering condition.

# %% [markdown]
# ### Handling categorical values

# %%
fifa_df.columns
# Out:
# Index(['sofifa_id', 'age', 'height_cm', 'weight_kg', 'nationality', 'club',
#        'overall', 'potential', 'value_eur', 'wage_eur', 'preferred_foot',
#        'international_reputation', 'weak_foot', 'skill_moves',
#        'release_clause_eur', 'contract_valid_until', 'pace', 'shooting',
#        'passing', 'dribbling', 'defending', 'physic', 'attacking_crossing',
#        'attacking_finishing', 'attacking_heading_accuracy',
#        'attacking_short_passing', 'attacking_volleys', 'skill_dribbling',
#        'skill_curve', 'skill_fk_accuracy', 'skill_long_passing',
#        'skill_ball_control', 'movement_acceleration', 'movement_sprint_speed',
#        'movement_agility', 'movement_reactions', 'movement_balance',
#        'power_shot_power', 'power_jumping', 'power_stamina', 'power_strength',
#        'power_long_shots', 'mentality_aggression', 'mentality_interceptions',
#        'mentality_positioning', 'mentality_vision', 'mentality_penalties',
# ...

# %%
first_condition = (fifa_df["nationality"].value_counts())/len(fifa_df)
second_condition = (fifa_df["club"].value_counts())/len(fifa_df)

fifa_df["nationality_encode"] = fifa_df["nationality"].apply(lambda x : first_condition[x])
fifa_df["club_encode"] = fifa_df["club"].apply(lambda y : second_condition[y])

# %%
fifa_df.drop(columns=["nationality","club"],inplace=True,axis=1)
fifa_df.head()
# Out:
#    sofifa_id  age  height_cm  weight_kg  overall  potential  value_eur  \
# 0     120533   36        188         81       84         84    6500000
# 1       5479   38        185         84       83         83    2600000
# 2     159261   36        180         79       83         83    9500000
# 3     168609   34        186         78       83         83    9500000
# 4      24630   36        188         92       82         82    3700000
#
#    wage_eur preferred_foot  international_reputation  ...  defending_marking  \
# 0     16000          Right                         4  ...                 86
# 1     11000           Left                         4  ...                 24
# 2     46000          Right                         2  ...                 35
# 3     32000          Right                         3  ...                 85
# 4     26000          Right                         3  ...                 20
#
# ...

# %%
fifa_df = pd.get_dummies(fifa_df,columns=["preferred_foot"])
fifa_df
# Out:
#        sofifa_id  age  height_cm  weight_kg  overall  potential  value_eur  \
# 0         120533   36        188         81       84         84    6500000
# 1           5479   38        185         84       83         83    2600000
# 2         159261   36        180         79       83         83    9500000
# 3         168609   34        186         78       83         83    9500000
# 4          24630   36        188         92       82         82    3700000
# ...          ...  ...        ...        ...      ...        ...        ...
# 17144     245006   22        186         79       48         56      40000
# 17145     250995   22        177         66       48         56      40000
# 17146     252332   19        186         75       48         56      40000
# 17147     251110   18        185         74       48         54      40000
# 17148     233449   26        182         78       48         51      40000
#
#        wage_eur  international_reputation  weak_foot  ...  \
# ...

# %%
fifa_df.shape
# Out:
# (17149, 57)

# %% [markdown]
# #### Insights:
#
# The *nationality* and *club* columns have been handled using **frequency encoding** and the *preferred_foot* column has been handled using **one hot encoding**.

# %% [markdown]
# ### Handling numerical values

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
fifa_df[["value_eur","wage_eur"]] = scaler.fit_transform(fifa_df[["value_eur","wage_eur"]])
fifa_df
# Out:
#        sofifa_id  age  height_cm  weight_kg  overall  potential  value_eur  \
# 0         120533   36        188         81       84         84   2.560225
# 1           5479   38        185         84       83         83   0.587290
# 2         159261   36        180         79       83         83   4.077867
# 3         168609   34        186         78       83         83   4.077867
# 4          24630   36        188         92       82         82   1.143759
# ...          ...  ...        ...        ...      ...        ...        ...
# 17144     245006   22        186         79       48         56  -0.707765
# 17145     250995   22        177         66       48         56  -0.707765
# 17146     252332   19        186         75       48         56  -0.707765
# 17147     251110   18        185         74       48         54  -0.707765
# 17148     233449   26        182         78       48         51  -0.707765
#
#        wage_eur  international_reputation  weak_foot  ...  \
# ...

# %%
from sklearn.preprocessing import MinMaxScaler

minmaxscaler = MinMaxScaler()
fifa_df[["age","height_cm","weight_kg","overall","potential","international_reputation","weak_foot","skill_moves","release_clause_eur","contract_valid_until","pace","shooting","passing","dribbling","defending","physic","attacking_crossing","attacking_finishing","attacking_heading_accuracy","attacking_short_passing","attacking_volleys","skill_dribbling","skill_curve","skill_fk_accuracy","skill_long_passing","skill_ball_control","movement_acceleration","movement_sprint_speed","movement_agility","movement_reactions","movement_balance","power_shot_power","power_jumping","power_stamina","power_strength","power_long_shots","mentality_aggression","mentality_interceptions","mentality_positioning","mentality_vision","mentality_penalties","mentality_composure","defending_marking","defending_standing_tackle","defending_sliding_tackle","goalkeeping_diving","goalkeeping_handling","goalkeeping_kicking","goalkeeping_positioning","goalkeeping_reflexes"]] = minmaxscaler.fit_transform(fifa_df[["age","height_cm","weight_kg","overall","potential","international_reputation","weak_foot","skill_moves","release_clause_eur","contract_valid_until","pace","shooting","passing","dribbling","defending","physic","attacking_crossing","attacking_finishing","attacking_heading_accuracy","attacking_short_passing","attacking_volleys","skill_dribbling","skill_curve","skill_fk_accuracy","skill_long_passing","skill_ball_control","movement_acceleration","movement_sprint_speed","movement_agility","movement_reactions","movement_balance","power_shot_power","power_jumping","power_stamina","power_strength","power_long_shots","mentality_aggression","mentality_interceptions","mentality_positioning","mentality_vision","mentality_penalties","mentality_composure","defending_marking","defending_standing_tackle","defending_sliding_tackle","goalkeeping_diving","goalkeeping_handling","goalkeeping_kicking","goalkeeping_positioning","goalkeeping_reflexes"]])
fifa_df
# Out:
#        sofifa_id       age  height_cm  weight_kg   overall  potential  \
# 0         120533  0.833333   0.651163       0.62  1.000000   0.897436
# 1           5479  0.916667   0.581395       0.68  0.972222   0.871795
# 2         159261  0.833333   0.465116       0.58  0.972222   0.871795
# 3         168609  0.750000   0.604651       0.56  0.972222   0.871795
# 4          24630  0.833333   0.651163       0.84  0.944444   0.846154
# ...          ...       ...        ...        ...       ...        ...
# 17144     245006  0.250000   0.604651       0.58  0.000000   0.179487
# 17145     250995  0.250000   0.395349       0.32  0.000000   0.179487
# 17146     252332  0.125000   0.604651       0.50  0.000000   0.179487
# 17147     251110  0.083333   0.581395       0.48  0.000000   0.128205
# 17148     233449  0.416667   0.511628       0.56  0.000000   0.051282
#
#        value_eur  wage_eur  international_reputation  weak_foot  ...  \
# ...

# %% [markdown]
# #### Insights:
#
# * The skewed columns have been handled using **StandardScaler**.
# * The non-skewed columns have been handled using **MinMaxScaler**.
